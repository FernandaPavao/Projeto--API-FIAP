# %%
import json
from pathlib import Path
import numpy as np

info = json.loads(open('data\processed\data_info.json', 'r', encoding='utf-8').read())
print(info['dataset_info']['features'])
print(info['shapes'])
# Out:
# ['Close', 'High', 'Low', 'Open', 'Volume', 'SMA_7', 'SMA_21', 'SMA_50', 'EMA_12', 'EMA_26', 'RSI', 'MACD', 'MACD_Signal', 'MACD_Hist', 'BB_Upper', 'BB_Lower', 'BB_Middle', 'Volatility', 'Daily_Return']
# {'X_train': [795, 60, 19], 'y_train': [795], 'X_val': [227, 60, 19], 'y_val': [227], 'X_test': [114, 60, 19], 'y_test': [114]}
# <>:5: SyntaxWarning: invalid escape sequence '\p'
# <>:5: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\andre\AppData\Local\Temp\ipykernel_3684\2093332323.py:5: SyntaxWarning: invalid escape sequence '\p'
#   info = json.loads(open('data\processed\data_info.json', 'r', encoding='utf-8').read())

# %%
DATA_DIR = Path('data/processed')
train = np.load(DATA_DIR / 'train_data.npz')
X_train, y_train = train['X_train'], train['y_train']
print("X_train", X_train.shape, "y_train", y_train.shape)
# Out:
# X_train (795, 60, 19) y_train (795,)
